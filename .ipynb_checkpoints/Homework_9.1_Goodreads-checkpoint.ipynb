# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors')
doc = BeautifulSoup(response.text)

# %%
books = []
for page_num in range(1, 15):
    url = f"https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page={page_num}"
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    print('Now Scraping', url)
    trs = doc.find_all('tr')
    
    for tr in trs:
        book = {}
        book['rank'] = tr.find(class_ = 'number').text
        book['title'] = tr.find('span').text
        book['author'] = tr.find(class_ = 'authorName').text
        book['score'] = tr.find(href="#").text
        book['vote'] = tr.find_all(href ="#")[1].text
        book['rating'] = tr.find(class_="minirating").text
        books.append(book)
        
print("Building our dataframe")
df = pd.DataFrame(books)
df = df[['rank','title','author','score','vote','rating']]
# Out:
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=1
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=2
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=3
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=4
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=5
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=6
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=7
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=8
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=9
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=10
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=11
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=12
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=13
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=14
# Building our dataframe

# %%
df.to_csv('Goodreads.csv')

# %%
response = requests.get('https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors')
doc = BeautifulSoup(response.text)

# %%
import re

books = []
for page_num in range(1, 15):
    url = f"https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page={page_num}"
    response = requests.get(url)
    doc = BeautifulSoup(response.text)
    print('Now Scraping', url)
    trs = doc.find_all('tr')

    for tr in trs:
        book = {}
        title = tr.find('span').text

        if '(' in title:
            
            regex1 = '(^.*)\s\(.*\#.*\)'
            try:
                tl = re.findall(regex1, title)[0]
                book['title'] = tl
            except:
                pass
            
            regex2 = '.*\s\((.*)\#.*\)'
            try:
                series = re.findall(regex2, title)[0]
                if ',' in series:
                    Series = re.findall('(.*),',series)[0]
                    book['series'] = Series
                else:
                    book['series'] = series
            except:
                pass
            
            regex3 = '.*\s\(.*\#(.*)\)'
            try:
                number_in_series = re.findall(regex3, title)
                book['number_in_series'] = number_in_series[0]
            except:
                pass
            
        else:
            book['title'] = title 
            book['series'] = '-'
            book['number_in_series'] = '-'
        score = tr.find(href="#").text
        Score = re.findall('score\:\s(.*)', score)
        book['score'] = Score[0]
        book['vote'] = tr.find_all(href ="#")[1].text
        rating = tr.find(class_="minirating").text
        Rating = re.findall('.*—\s(.*)\sratings',rating)
        try:
            book['number_of_ratings'] = Rating[0]
        except:
            pass
        books.append(book)
        
print("Building our dataframe")
Books = pd.DataFrame(books)
Books[['title','series','number_in_series','score','vote','number_of_ratings']]
# Out:
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=1
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=2
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=3
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=4
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=5
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=6
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=7
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=8
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=9
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=10
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=11
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=12
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=13
# Now Scraping https://www.goodreads.com/list/show/6934.Science_Fiction_Books_by_Female_Authors?page=14
# Building our dataframe
#                                                  title  \
# 0                                  The Handmaid's Tale
# 1                                     The Hunger Games
# 2                                         Frankenstein
# 3                                    A Wrinkle in Time
# 4                            The Left Hand of Darkness
# 5                                            Divergent
# 6                                        Catching Fire
# 7                                            The Giver
# 8                                              Kindred
# 9                                     The Dispossessed
# 10                                      Oryx and Crake
# 11                                          Mockingjay
# 12                            The Time Traveler's Wife
# 13                                       Doomsday Book
# 14                                 The Lathe of Heaven
# 15                                   Ancillary Justice
# 16                                   Shards of Honour
# 17                           To Say Nothing of the Dog
# 18                                         The Sparrow
# 19                                        Dragonflight
# 20                                Parable of the Sower
# 21                            The Warrior's Apprentice
# 22                                            Barrayar
# 23                                            The Host
# 24                                           Insurgent
# 25                                              Memory
# 26                                 The Children of Men
# 27                   Starshine: Aurora Rising Book One
# 28                              The Year of the Flood
# 29                                      Crystal Singer
# ...                                                ...
# 1365                                 Queenie's Brigade
# 1366                                          Hellfire
# 1367                   The Twisted Tale of Stormy Gale
# 1368                                Don’t Bite the Sun
# 1369                                     Journey's End
# 1370                         Dinosaur Planet Survivors
# 1371                                           Farseed
# 1372                            Drinking Sapphire Wine
# 1373                                     Body Electric
# 1374                               Generation Warriors
# 1375                                        Starjacked
# 1376                                   Alien Abduction
# 1377                                             Zazen
# 1378                                When Minds Collide
# 1379                                  Synthetic Dreams
# 1380                                          Lifegame
# 1381                                   Alien Seduction
# 1382                                      Fire & Frost
# 1383                                   The Inheritance
# 1384                              Children of the Dust
# 1385                                     The Sex Gates
# 1386                                Mizora: A Prophecy
# 1387  Northwest of Earth: The Complete Northwest Smith
# 1388                                  Tiger of Talmare
# 1389                                    Girl Gone Nova
# 1390                                    Black on Black
# 1391                                       Blue Nebula
# 1392                                  Stars Over Stars
# 1393                                    Heart of Steel
# 1394                                 The Imperium Game
#
#                         series number_in_series   score              vote  \
# 0                            -                -  30,733  314 people voted
# 1             The Hunger Games                1  28,553  292 people voted
# 2                            -                -  21,909  224 people voted
# 3                 Time Quintet                1  18,720  196 people voted
# 4               Hainish Cycle                 4  17,920  184 people voted
# 5                    Divergent                1  13,326  138 people voted
# 6             The Hunger Games                2  12,749  133 people voted
# 7                    The Giver                1  12,399  129 people voted
# 8                            -                -  11,070  116 people voted
# 9               Hainish Cycle                 6  10,731  112 people voted
# 10                   MaddAddam                1  10,117  107 people voted
# 11            The Hunger Games                3   9,807  104 people voted
# 12                           -                -   9,193   98 people voted
# 13          Oxford Time Travel                1   8,935   96 people voted
# 14                           -                -   7,775   84 people voted
# 15             Imperial Radch                 1   7,336   81 people voted
# 16             Vorkosigan Saga                1   7,017   75 people voted
# 17          Oxford Time Travel                2   6,890   74 people voted
# 18                 The Sparrow                1   6,873   72 people voted
# 19        Dragonriders of Pern                1   6,802   74 people voted
# 20                   Earthseed                1   6,653   71 people voted
# 21             Vorkosigan Saga                2   6,087   65 people voted
# 22             Vorkosigan Saga                7   5,623   60 people voted
# 23                    The Host                1   5,274   56 people voted
# 24                   Divergent                2   4,899   54 people voted
# 25             Vorkosigan Saga               10   4,682   51 people voted
# 26                           -                -   4,484   49 people voted
# 27             Aurora Rhapsody                1   4,394   45 people voted
# 28                   MaddAddam                2   4,343   47 people voted
# 29              Crystal Singer                1   4,235   47 people voted
# ...                        ...              ...     ...               ...
# 1365                         -                -      14    1 person voted
# 1366  Theirs Not to Reason Why                3      14    1 person voted
# 1367               Stormy Gale                1      13    1 person voted
# 1368                  Four-BEE                1      13    1 person voted
# 1369                         -                -      12    1 person voted
# 1370           Dinosaur Planet                2      12    1 person voted
# 1371                      Seed                2      12    1 person voted
# 1372                  Four-BEE                2      12    1 person voted
# 1373                         -                -      11    1 person voted
# 1374            Planet Pirates                3      11    1 person voted
# 1375                         -                -      10    1 person voted
# 1376          Beastmen of Ator                1      10    1 person voted
# 1377                         -                -       8    1 person voted
# 1378               Phoenician               0.1       7    1 person voted
# 1379                         -                -       6    1 person voted
# 1380                         -                -       6    1 person voted
# 1381    Ailunnean Shapeshifter                2       5    1 person voted
# 1382                         -                -       5    1 person voted
# 1383                         -                -       5    1 person voted
# 1384                         -                -       5    1 person voted
# 1385                 Sex Gates                1       4    1 person voted
# 1386                         -                -       4    1 person voted
# 1387                         -                -       4    1 person voted
# 1388         Frontiers of Love                1       3    1 person voted
# 1389        Project Enterprise                2       3    1 person voted
# 1390         Heyoka Blackeagle                1       3    1 person voted
# 1391                         -                -       2    1 person voted
# 1392         Heyoka Blackeagle                2       2    1 person voted
# 1393                 Iron Seas                2       1    1 person voted
# 1394                         -                -       1    1 person voted
#
#      number_of_ratings
# 0            1,101,884
# 1            5,741,960
# 2            1,023,349
# 3              903,025
# 4               98,763
# 5            2,602,477
# 6            2,200,531
# 7            1,534,919
# 8               72,314
# 9               71,627
# 10             197,757
# 11           2,071,811
# 12           1,446,639
# 13              43,250
# 14              43,984
# 15              66,191
# 16              25,871
# 17              29,640
# 18              52,733
# 19             116,151
# 20              42,219
# 21              20,954
# 22              22,110
# 23             828,949
# 24           1,045,745
# 25              13,947
# 26              36,101
# 27               2,146
# 28              92,215
# 29              17,772
# ...                ...
# 1365                27
# 1366             2,265
# 1367               386
# 1368               583
# 1369                 4
# 1370             2,713
# 1371               160
# 1372               544
# 1373               149
# 1374             3,334
# 1375                62
# 1376               233
# 1377             1,223
# 1378                27
# 1379                63
# 1380                66
# 1381                 4
# 1382               877
# 1383             3,198
# 1384             1,612
# 1385               106
# 1386                88
# 1387               250
# 1388               398
# 1389               170
# 1390               423
# 1391                13
# 1392               297
# 1393             5,446
# 1394                35
#
# [1395 rows x 6 columns]

# %%
Books.to_csv('Goodreads_cleaned.csv')
